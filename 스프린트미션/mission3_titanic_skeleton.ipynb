# %% [markdown]
# # [스프린트 미션 3] Skeleton: 캐글 타이타닉 생존자 예측
#
# 이 노트북은 **뼈대만 제공하는 버전**입니다. 환경 설정, 데이터 받기, 제출하기만 준비되어 있고 나머지는 전부 비어 있어요.
# EDA부터 모델 튜닝까지 전 과정을 스스로 설계하고 싶다면 이 버전으로 시작하세요. 각 단계의 예시 코드가 필요하다면 가이드형 Baseline 노트북을 참고하면 됩니다.
#
# 섹션 구성은 하나의 제안일 뿐입니다. 필요하면 섹션을 합치거나 나누거나 순서를 바꿔도 좋아요.

# %% [markdown]
# ## 1. 설정

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
print("설정 완료")

# %%
# matplotlib 한글 깨짐 방지 (Colab)
# !apt-get update -qq
# !apt-get install -y -qq fonts-nanum*
# !rm -rf ~/.cache/matplotlib

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action="ignore")

path = "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf"  # 나눔바른고딕
fm.fontManager.addfont(path)
plt.rc("font", family=fm.FontProperties(fname=path).get_name())

# %% [markdown]
# ## 2. Kaggle CLI로 데이터 받기
# [대회 페이지](https://www.kaggle.com/c/titanic)에서 **Join Competition**을 먼저 누른 뒤 진행하세요. (참가하지 않으면 다운로드에서 403 에러가 납니다)
# 1. 캐글 프로필 사진 \> Settings \> API에서 토큰을 생성하고, `KGAT_`로 시작하는 문자열을 복사해 두세요.
# 2. Colab 왼쪽 사이드바의 🔑(보안 비밀) 탭에서 이름은 `KAGGLE_API_TOKEN`, 값은 복사해 둔 토큰으로 저장하고, "노트북 액세스"를 켜 주세요. 한 번 저장해 두면 런타임이 초기화되거나 노트북을 새로 만들어도 계속 쓸 수 있습니다.
#
# > 토큰을 노트북 셀에 직접 붙여넣지 마세요. 제출한 노트북에 토큰이 그대로 남습니다.

# %%
# %pip install -q --upgrade kaggle  # KGAT_ 토큰 인증은 최신 버전에서 지원됩니다.

import os
from google.colab import userdata

# Colab 보안 비밀에 저장해 둔 토큰을 환경 변수로 등록합니다.
os.environ["KAGGLE_API_TOKEN"] = userdata.get("KAGGLE_API_TOKEN")

# !kaggle competitions download -c titanic
# !unzip -q titanic.zip -d data
# !ls data

# %%
train_df = pd.read_csv("data/train.csv")
test_df = pd.read_csv("data/test.csv")

print("train:", train_df.shape, "| test:", test_df.shape)
train_df.head()

# %% [markdown]
# ---
# ## 3. EDA
# 데이터를 훑어보고 전처리 방향을 정하세요. 결측치 분포, 타깃과 피처의 관계 정도는 확인하고 넘어가는 것을 추천합니다.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## 4. 피처 엔지니어링
# 데이터 정의서를 보며 파생 변수를 설계하세요. `train`과 `test`에 동일하게 적용해야 한다는 점만 기억해 주세요.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## 5. 전처리와 데이터 분할
# 결측치 처리, 인코딩, 스케일링 방식을 정하고 검증 전략(홀드아웃, 교차 검증 등)을 설계하세요.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## 6. 모델 실험
# 여러 모델을 실험하고 결과를 비교하세요. 실험이 쌓일수록 하이퍼파라미터와 점수를 표로 관리하는 것이 힘을 발휘합니다. 자신만의 실험 기록 방식을 만들어 보세요.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## 7. 하이퍼파라미터 튜닝

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## 8. 최종 평가
# 최종 모델을 고른 근거를 남기세요. Confusion Matrix, Feature Importance 같은 도구가 근거를 만드는 데 도움이 됩니다.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
# ## 9. 제출 파일 만들고 캐글에 제출하기
# 제출 파일은 `PassengerId`와 `Survived`(0 또는 1) 두 컬럼이어야 합니다.

# %%
# TODO: 최종 모델로 test 데이터를 예측한 결과를 predictions에 담으세요.
predictions = ...

submission = pd.DataFrame({
    "PassengerId": test_df["PassengerId"],
    "Survived": predictions.astype(int),
})
submission.to_csv("submission.csv", index=False)
print(submission.shape)
submission.head()

# %%
# ⚠️ 이 셀은 실행할 때마다 하루 제출 기회(10번)를 1번 사용합니다.
# [런타임 > 모두 실행]에 휩쓸려 제출되지 않도록 주석으로 막아 뒀어요.
# 진짜 제출할 준비가 되면 아래 한 줄의 주석(#)을 지우고, 이 셀만 실행하세요.
# -m 뒤의 메시지에는 어떤 실험이었는지 적어 두세요.

# !kaggle competitions submit -c titanic -f submission.csv -m "..."

# 제출 이력과 점수 확인은 제출 기회를 쓰지 않으니 자유롭게 실행해도 됩니다.
# !kaggle competitions submissions -c titanic

# %% [markdown]
# ---
# ## 제출 전 체크리스트
# - 각 단계의 의도와 결론이 마크다운으로 설명되어 있나요?
# - 여러 모델을 비교한 결과와 최종 모델 선택 이유가 정리되어 있나요?
# - 리더보드 점수 캡처를 넣었나요?
# - 파일명이 `03_{팀명}_{성함}.ipynb`인가요?
