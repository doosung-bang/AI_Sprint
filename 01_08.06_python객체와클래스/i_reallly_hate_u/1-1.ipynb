# %% [markdown]
# # Chapter 01 흩어진 데이터를 객체로 묶기
# 실행 결과를 먼저 예측하고 TODO만 수정하세요.

# %%
class MenuItem:
    def __init__(self, name, price):
        # TODO 1: 전달받은 이름과 가격을 객체에 저장하세요.
        raise NotImplementedError('__init__()을 구현하세요.')

    def apply_discount(self, discount_rate):
        # TODO 2: 0~1 사이의 할인율만 허용하고 가격을 정수로 변경하세요.
        # 범위를 벗어나면 ValueError를 발생시키세요.
        raise NotImplementedError('apply_discount()를 구현하세요.')

    def __str__(self):
        # TODO 3: 아메리카노: 4,000원 형식으로 반환하세요.
        raise NotImplementedError('__str__()을 구현하세요.')


try:
    coffee = MenuItem('아메리카노', 5000)
    tea = MenuItem('녹차', 4500)

    assert coffee.name == '아메리카노'
    assert coffee.price == 5000
    assert tea.price == 4500
    assert str(coffee) == '아메리카노: 5,000원'

    coffee.apply_discount(0.2)
    assert coffee.price == 4000
    assert tea.price == 4500, '한 객체의 변경이 다른 객체에 영향을 주면 안 됩니다.'
    assert str(coffee) == '아메리카노: 4,000원'

    try:
        coffee.apply_discount(1.5)
    except ValueError:
        pass
    else:
        raise AssertionError('할인율이 범위를 벗어나면 ValueError가 필요합니다.')

except (AssertionError, NotImplementedError, TypeError, ValueError) as error:
    print('미완료')
    print('확인할 내용:', error)
else:
    print('모든 테스트를 통과')
# Out:
# 미완료
# 확인할 내용: __init__()을 구현하세요.

# %%
print(round(1.6))
# Out:
# 2

# %%
class MenuItem:
    def __init__(self, name, price):
        # TODO 1: 전달받은 이름과 가격을 객체에 저장하세요.
        self.name = name
        self.price = price

    def apply_discount(self, discount_rate):
        # TODO 2: 0~1 사이의 할인율만 허용하고 가격을 정수로 변경하세요.
        # 범위를 벗어나면 ValueError를 발생시키세요.
        if not 0 <= discount_rate <= 1:
            raise ValueError('할인율은 0 이상 1 이하여야 합니다.')
        self.price = round(self.price * (1 - discount_rate))

    def __str__(self):
        # TODO 3: 아메리카노: 4,000원 형식으로 반환하세요.
        return f'{self.name}: {self.price:,}원'


try:
    coffee = MenuItem('아메리카노', 5000)
    tea = MenuItem('녹차', 4500)

    assert coffee.name == '아메리카노'
    assert coffee.price == 5000
    assert tea.price == 4500
    assert str(coffee) == '아메리카노: 5,000원'

    coffee.apply_discount(0.2)
    assert coffee.price == 4000
    assert tea.price == 4500, '한 객체의 변경이 다른 객체에 영향을 주면 안 됩니다.'
    assert str(coffee) == '아메리카노: 4,000원'

    try:
        coffee.apply_discount(1.5)
    except ValueError:
        pass
    else:
        raise AssertionError('할인율이 범위를 벗어나면 ValueError가 필요합니다.')

except (AssertionError, NotImplementedError, TypeError, ValueError) as error:
    print('미완료')
    print('확인할 내용:', error)
else:
    print('테스트 통과.')
# Out:
# 테스트 통과.

# %%
class MenuItem:
    def __init__(self, name, price):
        # TODO 1: 전달받은 이름과 가격을 객체에 저장하세요.
        # raise NotImplementedError('__init__()을 구현하세요.')
        self.name = name
        self.price = price

    def apply_discount(self, discount_rate):
        # TODO 2: 0~1 사이의 할인율만 허용하고 가격을 정수로 변경하세요.
        # 범위를 벗어나면 ValueError를 발생시키세요.
        # raise NotImplementedError('apply_discount()를 구현하세요.')
        if not 0 <= discount_rate <= 1:
          raise ValueError('할인율은 0 이상 1 이하여야 합니다.')

        self.price = round(self.price * (1 - discount_rate))

    def __str__(self):
        # TODO 3: 아메리카노: 4,000원 형식으로 반환하세요.
        # raise NotImplementedError('__str__()을 구현하세요.')
        return(f'{self.name} : {self.price:,}원')

# %%
class MenuItem:
    def __init__(self, name, price):
        # TODO 1: 전달받은 이름과 가격을 객체에 저장하세요.
        # raise NotImplementedError('__init__()을 구현하세요.')
        self.name = name
        self.price = price

    def apply_discount(self, discount_rate):
        # TODO 2: 0~1 사이의 할인율만 허용하고 가격을 정수로 변경하세요.
        # 범위를 벗어나면 ValueError를 발생시키세요.
        # raise NotImplementedError('apply_discount()를 구현하세요.')
        if not 0 <= discount_rate <= 1:
          raise ValueError('할인율은 0 이상 1 이하여야 합니다.')

        self.price = round(self.price * (1 - discount_rate))

    def __str__(self):
        # TODO 3: 아메리카노: 4,000원 형식으로 반환하세요.
        # raise NotImplementedError('__str__()을 구현하세요.')
        return(f'{self.name}: {self.price:,}원')


try:
    coffee = MenuItem('아메리카노', 5000)
    tea = MenuItem('녹차', 4500)

    assert coffee.name == '아메리카노'
    assert coffee.price == 5000
    assert tea.price == 4500
    assert str(coffee) == '아메리카노: 5,000원'

    coffee.apply_discount(0.2)
    assert coffee.price == 4000
    assert tea.price == 4500, '한 객체의 변경이 다른 객체에 영향을 주면 안 됩니다.'
    assert str(coffee) == '아메리카노: 4,000원'

    try:
        coffee.apply_discount(1.5)
    except ValueError:
        pass
    else:
        raise AssertionError('할인율이 범위를 벗어나면 ValueError가 필요합니다.')

except (AssertionError, NotImplementedError, TypeError, ValueError) as error:
    print('미완료')
    print('확인할 내용:', error)
else:
    print('테스트 통과.')
# Out:
# 테스트 통과.
