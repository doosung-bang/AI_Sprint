# %% [markdown]
# # PyTorch Foundation · Day 01 Practice Q
#
# P01→P15를 강의 순서대로 수행함. 각 문제는 독립 `pXX_*` 상태를 사용함.
#
# - 실행 전에 결과와 shape를 먼저 예상함
# - 답과 예상 숫자는 이 파일에 없음
# - 막히면 Hint 1 → 필요할 때만 Hint 2 순서로 확인함
# - 결과를 만든 뒤 반드시 어떤 출력이 근거인지 한 문장으로 씀
# - Practice A는 시도와 실행이 끝난 뒤 확인함

# %%
# %pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# ...
#    ---------------------------------------- 0.0/124.1 MB ? eta -:--:--
#    - -------------------------------------- 5.5/124.1 MB 27.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 14.7/124.1 MB 35.5 MB/s eta 0:00:04
#    -------- ------------------------------- 25.2/124.1 MB 39.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 34.6/124.1 MB 41.0 MB/s eta 0:00:03
#    -------------- ------------------------- 44.0/124.1 MB 41.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 51.9/124.1 MB 40.9 MB/s eta 0:00:02
#    ------------------- -------------------- 61.1/124.1 MB 41.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 70.8/124.1 MB 41.7 MB/s eta 0:00:02
#    -------------------------- ------------- 81.0/124.1 MB 42.3 MB/s eta 0:00:02
# ...

# %%
import torch
print('practice runtime ready')
print("pyTorch verison:", torch.__version__)
# Out:
# practice runtime ready
# pyTorch verison: 2.14.0+cpu

# %% [markdown]
# ## P01 · Tensor creation
#
# **한 줄 why**: 값만 맞추지 않고 값·shape·dtype·device를 함께 읽기 위함
#
# **문제**: `[10,20,30,40]` vector, `[2,3]` zeros와 ones, `1..12` 연속값, seed 7의 `[2,2]` 난수 Tensor를 만듦.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 다섯 Tensor의 값·shape·dtype·device 출력 / 요구한 값과 축 구조 점검함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 만들 값의 규칙과 원하는 축 길이를 먼저 분리함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `torch.tensor`, `zeros`, `ones`, `arange`, `randn`
# </details>

# %%
torch.manual_seed(7)
p01_vector = None
p01_zeros = None
p01_ones = None
p01_range = None
p01_noise = None

# 학습자 작성 영역
p01_vector = torch.arange(10,40,10)
p01_zeros = torch.zeros(2,3)
p01_ones = torch.ones(1,1)
p01_range = torch.arange()
p01_noise = torch.randn()


p01_items = [p01_vector, p01_zeros, p01_ones, p01_range, p01_noise]
for p01_value in p01_items:
    if p01_value is not None:
        print(p01_value, list(p01_value.shape), p01_value.dtype, p01_value.device.type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5 p01_range = None
#       6 p01_noise = None
#       7
#       8 # 학습자 작성 영역
# ----> 9 p01_vector = arange(10,40)
#      10
#      11 p01_items = [p01_vector, p01_zeros, p01_ones, p01_range, p01_noise]
#      12 for p01_value in p01_items:
#
# NameError: name 'arange' is not defined

# %% [markdown]
# ## P02 · Indexing/slicing
#
# **한 줄 why**: 값 선택과 축 유지·제거를 함께 보기 위함
#
# **문제**: `[4,5]` Tensor에서 세 번째 행, 세 번째 행을 길이 1 slice로 유지한 결과, 마지막 열, `1:3`행·`1:4`열을 꺼냄.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 실행 전 shape 네 개 기록 / 실제 값·shape와 비교함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 정수 index와 slice가 해당 축을 어떻게 다루는지 구분함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# 두 축을 `[행, 열]` 순서로 작성함
# </details>

# %%
p02_base = torch.arange(20).reshape(4, 5)
# 예상 shape: ____ / ____ / ____ / ____
p02_third_row = None
p02_third_row_slice = None
p02_last_column = None
p02_middle = None

# 학습자 작성 영역

for p02_value in [p02_third_row, p02_third_row_slice, p02_last_column, p02_middle]:
    if p02_value is not None:
        print(p02_value.tolist(), list(p02_value.shape))

# %% [markdown]
# ## P03 · Shape operations
#
# **한 줄 why**: 원소 수와 축 변화를 분리해 읽기 위함
#
# **문제**: 12개 값 `[3,4]→[2,6]`, `[3,1,4]→[3,4]`, `[4]→[4,1]`, `[3,4]→[1,3,4]`를 만듦.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 네 shape 출력 / 원소 수 유지 / 추가·제거 축 크기 1 설명함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# reshape 전후 shape 곱을 비교하고 길이 1인 축을 찾음
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `reshape`, `squeeze(axis)`, `unsqueeze(axis)`
# </details>

# %%
p03_base = torch.arange(12).reshape(3, 4)
p03_axis = torch.arange(12).reshape(3, 1, 4)
p03_vector = torch.arange(4)
p03_reshaped = None
p03_squeezed = None
p03_column = None
p03_front = None

# 학습자 작성 영역

if all(v is not None for v in [p03_reshaped,p03_squeezed,p03_column,p03_front]):
    print([list(v.shape) for v in [p03_reshaped,p03_squeezed,p03_column,p03_front]])
    print([v.numel() for v in [p03_reshaped,p03_squeezed,p03_column,p03_front]])

# %% [markdown]
# ## P04 · cat/stack
#
# **한 줄 why**: 기존 축 연장과 새 축 생성을 구분하기 위함
#
# **문제**: 두 `[2,3]` Tensor의 `cat(dim=0/1)`과 `stack(dim=0/1)`을 만들고 shape와 한 slice를 확인함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 네 shape 사전 예상 / cat·stack 축 의미 설명 / stack slice 한 개 확인함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# cat은 기존 숫자 하나를 늘리고 stack은 숫자 하나를 새로 넣음
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `torch.cat`, `torch.stack`
# </details>

# %%
p04_a = torch.ones(2, 3)
p04_b = torch.zeros(2, 3)
p04_cat0 = None
p04_cat1 = None
p04_stack0 = None
p04_stack1 = None

# 학습자 작성 영역

if all(v is not None for v in [p04_cat0,p04_cat1,p04_stack0,p04_stack1]):
    print([list(v.shape) for v in [p04_cat0,p04_cat1,p04_stack0,p04_stack1]])

# %% [markdown]
# ## P05 · Broadcasting trap
#
# **한 줄 why**: 실행 성공과 의미 성공을 구분하기 위함
#
# **문제**: `[3,1]` prediction과 `[3]` target의 error table을 읽고 샘플별 비교 shape로 고침.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 수정 전·후 input/error shape와 loss 비교 / 9개 비교가 생긴 이유 설명함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 오른쪽부터 축을 맞추고 한 prediction이 몇 target과 비교되는지 셈
# </details>
#
# <details><summary>Hint 2 · API</summary>
# target에 크기 1인 마지막 축을 추가함
# </details>

# %%
p05_prediction = torch.tensor([[1.0],[2.0],[3.0]])
p05_target = torch.tensor([1.0,2.0,3.0])
p05_wrong_error = p05_prediction - p05_target
print("wrong table:", p05_wrong_error, list(p05_wrong_error.shape))
p05_fixed_target = None

# 학습자 작성 영역

if p05_fixed_target is not None:
    p05_fixed_error = p05_prediction - p05_fixed_target
    print("fixed:", list(p05_fixed_error.shape), ((p05_fixed_error**2).mean()).item())

# %% [markdown]
# ## P06 · matmul
#
# **한 줄 why**: 원소곱과 feature 결합을 분리해 읽기 위함
#
# **문제**: `[2,3]` 원소곱과 `[2,3]@[3,2]`를 계산하고, `[5,3]@[3,2]`의 batch·feature·output 의미를 적음.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: shape 사전 예상 / 첫 output 손 계산 / 안쪽·바깥 축 의미 설명함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# `*`는 같은 위치, `@`는 한 행과 한 열의 곱을 더함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `left @ weight`
# </details>

# %%
p06_left = torch.tensor([[1.,2.,3.],[4.,5.,6.]])
p06_same = torch.tensor([[2.,2.,2.],[3.,3.,3.]])
p06_weight = torch.tensor([[1.,0.],[0.,1.],[1.,1.]])
p06_elementwise = None
p06_matmul = None
p06_batch = torch.arange(15, dtype=torch.float32).reshape(5,3)
p06_batch_output = None

# 학습자 작성 영역

for p06_value in [p06_elementwise,p06_matmul,p06_batch_output]:
    if p06_value is not None:
        print(list(p06_value.shape), p06_value.tolist())

# %% [markdown]
# ## P07 · wx+b
#
# **한 줄 why**: input과 학습으로 바뀔 parameter를 구분하기 위함
#
# **문제**: x=2에서 `(w,b)=(1,0),(2,0),(1,3)` prediction을 계산하고 w/b의 효과를 설명함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 세 prediction 출력 / input·parameter·prediction 역할 표시함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# `w*x` 변화와 마지막 더하기 변화를 나눔
# </details>

# %%
p07_x = torch.tensor(2.0)
p07_cases = [(1.0,0.0),(2.0,0.0),(1.0,3.0)]
for p07_w_value,p07_b_value in p07_cases:
    p07_prediction = None
    # 학습자 작성 영역
    if p07_prediction is not None:
        print(p07_w_value,p07_b_value,p07_prediction.item())

# %% [markdown]
# ## P08 · MSE
#
# **한 줄 why**: error 여러 개가 loss 하나가 되는 경로와 shape 조건을 보기 위함
#
# **문제**: prediction `[2,4,6]`, target `[3,5,4]`의 error·square·mean을 손 계산한 뒤 `[3,1]` 대 `[3]` trap도 고침.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 손 계산과 코드 비교 / wrong·fixed error shape와 loss 비교 / loss가 update가 아님을 설명함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# prediction-target → square → mean 순서로 적음
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `**2`, `.mean()`, `unsqueeze(1)`
# </details>

# %%
p08_prediction = torch.tensor([2.,4.,6.])
p08_target = torch.tensor([3.,5.,4.])
p08_error = None
p08_squared = None
p08_mse = None
p08_prediction_col = p08_prediction.unsqueeze(1)
p08_target_col = None

# 학습자 작성 영역

if all(v is not None for v in [p08_error,p08_squared,p08_mse]):
    print(p08_error, p08_squared, p08_mse)
if p08_target_col is not None:
    print(list((p08_prediction_col-p08_target).shape), list((p08_prediction_col-p08_target_col).shape))

# %% [markdown]
# ## P09 · scalar autograd
#
# **한 줄 why**: gradient 숫자 전에 방향과 backward 책임을 분리하기 위함
#
# **문제**: x=3, y=x²에서 gradient 부호를 먼저 적고 backward 뒤 x와 x.grad를 확인함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 부호 사전 예상 / x.grad 확인 / x unchanged 설명함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# x를 조금 키우면 x²이 커질지 생각함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `y.backward()` 뒤 `x.grad` 확인
# </details>

# %%
p09_x = torch.tensor(3.0, requires_grad=True)
p09_y = p09_x**2
# 예상 gradient 부호: ____
# 학습자 작성 영역: backward와 출력

# %% [markdown]
# ## P10 · accumulation/reset
#
# **한 줄 why**: 반복 학습에서 gradient memory를 정리하는 이유를 보기 위함
#
# **문제**: w=1,b=0,x=2,target=5에서 first backward, 새 forward의 second backward, reset 출력을 예상함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 세 시점 grad 예상 / 누적 설명 / reset 뒤 parameter 유지 확인함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 새 gradient가 기존 `.grad`를 교체하는지 더하는지 생각함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# 새 loss를 만든 뒤 backward, 마지막에 `zero_()`
# </details>

# %%
p10_x=torch.tensor(2.0)
p10_y=torch.tensor(5.0)
p10_w=torch.tensor(1.0,requires_grad=True)
p10_b=torch.tensor(0.0,requires_grad=True)
# 예상 first: ____ / second: ____ / reset: ____
# 학습자 작성 영역

# %% [markdown]
# ## P11 · manual update
#
# **한 줄 why**: backward·update·reset의 책임 순서를 조립하기 위함
#
# **문제**: x=2,target=5,w=1,b=0,lr=0.05에서 한 학습 단계를 완성함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: before·gradient·after·reset 출력 / 새 prediction/loss 계산 / backward와 update를 다른 줄로 표시함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 계산한 gradient를 사용한 뒤 다음 계산을 위해 비움
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `backward`, `torch.no_grad`, `zero_`
# </details>

# %%
p11_x=torch.tensor(2.0)
p11_y=torch.tensor(5.0)
p11_w=torch.tensor(1.0,requires_grad=True)
p11_b=torch.tensor(0.0,requires_grad=True)
p11_lr=0.05
# 1 prediction
p11_prediction=None
# 2 loss
p11_loss=None
# 3 backward와 gradient 기록
p11_grad_w=None; p11_grad_b=None
# 4 no_grad update
# 5 reset
# 6 fresh prediction/loss
p11_new_prediction=None; p11_new_loss=None
# 학습자 작성 영역

# %% [markdown]
# ## P12 · manual linear regression integration
#
# **한 줄 why**: Day01의 다섯 학습 책임을 독립 loop로 연결하기 위함
#
# **문제**: y=2x+1 네 점에서 w=b=0,lr=0.1로 21회 학습함. 5회마다 update 전 상태를 출력함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: prediction/target `[4,1]` assert / forward→MSE→backward→update→reset / epoch 00·05·10·15·20 출력함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 현재 loss의 gradient를 만든 뒤 사용하고 다음 반복 전에 정리함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# P11의 여섯 단계를 loop 안에 배치함
# </details>

# %%
p12_x=torch.tensor([[0.],[1.],[2.],[3.]])
p12_y=torch.tensor([[1.],[3.],[5.],[7.]])
p12_w=torch.tensor(0.,requires_grad=True)
p12_b=torch.tensor(0.,requires_grad=True)
p12_lr=0.1
for p12_step in range(21):
    p12_prediction=None
    if p12_prediction is not None:
        assert p12_prediction.shape==p12_y.shape==torch.Size([4,1])
    p12_loss=None
    if p12_prediction is not None and p12_loss is not None:
        if p12_step%5==0:
            print(p12_step,p12_w.item(),p12_b.item(),p12_loss.item())
        # 학습자 작성 영역: backward → update → reset
        pass

# %% [markdown]
# ## P13 · learning-rate experiment
#
# **한 줄 why**: gradient 정보와 update scale을 분리하기 위함
#
# **문제**: 같은 네 점과 새 w=b=0에서 lr 0.01,0.1,0.5의 한 step을 비교함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 같은 시작·gradient 확인 / w,b 이동과 새 loss 비교 / 보편적 best 주장하지 않음
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 각 실행이 새 parameter에서 시작하는지 확인함
# </details>
#
# <details><summary>Hint 2 · API</summary>
# update 식의 lr만 바꿈
# </details>

# %%
p13_x=torch.tensor([[0.],[1.],[2.],[3.]])
p13_y=torch.tensor([[1.],[3.],[5.],[7.]])
def p13_one_step(p13_lr):
    p13_w=torch.tensor(0.,requires_grad=True)
    p13_b=torch.tensor(0.,requires_grad=True)
    # 학습자 작성 영역
    return None
for p13_lr in [0.01,0.1,0.5]:
    p13_result=p13_one_step(p13_lr)
    if p13_result is not None:
        print(p13_lr,p13_result)

# %% [markdown]
# ## P14 · final retrieval
#
# **한 줄 why**: 처음 보는 코드에서도 Day01 학습 구조를 찾기 위함
#
# **문제**: 아래 코드에서 Tensor, input, parameter, prediction, loss, gradient 계산, update, reset을 표시하고 여섯 문장을 자기 말로 완성함.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 결과 해석: `________________`
#
# **answer-safe 완료 조건**: 여덟 역할 표시 / backward와 update를 다른 줄로 가리킴 / 자기 말 설명함
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 값 준비→예측→틀림 측정→방향 계산→값 수정→정리로 나눔
# </details>

# %%
p14_feature=torch.tensor([1.,3.])
p14_answer=torch.tensor([4.,8.])
p14_scale=torch.tensor(0.5,requires_grad=True)
p14_offset=torch.tensor(1.,requires_grad=True)
p14_estimate=p14_scale*p14_feature+p14_offset
p14_distance=((p14_estimate-p14_answer)**2).mean()
p14_distance.backward()
with torch.no_grad():
    p14_scale-=0.05*p14_scale.grad
    p14_offset-=0.05*p14_offset.grad
p14_scale.grad.zero_(); p14_offset.grad.zero_()

# 학습자 작성 영역: 각 줄의 역할 표시와 자기 말 설명

print('역할 표시를 마친 뒤 parameter와 gradient reset 상태를 확인함')

# %% [markdown]
# ## P15 · dtype 자동 승격 관찰
#
# **한 줄 why**: 에러 없이 계산되어도 dtype이 조용히 바뀔 수 있음을 보기 위함
#
# **문제**: 정수 범주 번호 `labels`와 실수 `scores`를 곱하기 전에 결과 dtype을 예상하고 실행함. 그다음 관찰을 위해 `labels.float()`로 바꾼 별도 Tensor를 만들어 두 결과를 비교함.
#
# > 이 실습은 **dtype 승격 관찰용**임. 분류 정답 라벨을 항상 float로 바꾸라는 규칙이 아님. 분류 loss가 요구하는 target dtype은 사용하는 loss의 계약을 따름.
#
# **학습자 기록**
#
# - 실행 전 예상: `________________`
# - 자동 승격에서 관찰한 것: `________________`
# - `.float()`가 일반 처방이 아닌 이유: `________________`
#
# <details><summary>Hint 1 · 사고 방향</summary>
# 입력 두 개와 결과의 dtype을 각각 출력해 비교함.
# </details>
#
# <details><summary>Hint 2 · API</summary>
# `.dtype`, `.float()`
# </details>

# %%
p15_labels = torch.tensor([0, 1, 2])
p15_scores = torch.tensor([0.1, 0.8, 0.3])
p15_total = p15_labels * p15_scores

print("before:", p15_labels.dtype, p15_scores.dtype, "→", p15_total.dtype)

p15_labels_float = None  # 관찰을 위해 새 Tensor를 만들어봄

if p15_labels_float is not None:
    p15_total_float = p15_labels_float * p15_scores
    print("after: ", p15_labels_float.dtype, p15_scores.dtype, "→", p15_total_float.dtype)
else:
    print("labels.float() 결과를 별도 변수에 담아 비교함")
