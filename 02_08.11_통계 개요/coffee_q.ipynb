# %% [markdown]
# ---
#
# ## 준비

# %%
# [1/3] 한글 폰트 설치 (런타임을 새로 켤 때마다 한 번씩 실행)
# !apt-get install -y fonts-nanum > /dev/null 2>&1
# !ls /usr/share/fonts/truetype/nanum/
# !pwd
# Out:
# ������ ��θ� ã�� �� �����ϴ�.
# 'ls'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 1. 네이버 나눔글꼴 배포 파일 다운로드 및 압축 해제
# !powershell -Command "Invoke-WebRequest -Uri 'https://github.com' -OutFile 'nanum.zip'"
# !powershell -Command "Expand-Archive -Path 'nanum.zip' -DestinationPath 'nanum_fonts' -Force"

# 2. 설치된 폰트 파일 목록 확인 (리눅스의 ls 역할)
# !dir nanum_fonts\*.ttf
# Out:
# New-Object : "3"���� �μ��� �ִ� ".ctor"��(��) ȣ���ϴ� ���� ���ܰ� �߻��߽��ϴ�. "�߾� ���͸��� �� ���ڵ带 ã�� ��
# �����ϴ�."
# ��ġ
# C:\WINDOWS\system32\WindowsPowerShell\v1.0\Modules\Microsoft.PowerShell.Archive\Microsoft.PowerShell.Archive.psm1:934
# ����:23
# + ... ipArchive = New-Object -TypeName System.IO.Compression.ZipArchive -Ar ...
# +                 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : InvalidOperation: (:) [New-Object], MethodInvocationException
#     + FullyQualifiedErrorId : ConstructorInvokedThrowException,Microsoft.PowerShell.Commands.NewObjectCommand
#  G ����̺��� ����: Google Drive
#  ���� �Ϸ� ��ȣ: 1983-1116
#
#  g:\�� ����̺�\Codeit\Sprint(AI�����Ͼ�)\02_08.11_��� ����\nanum_fonts ���͸�
# ������ ã�� �� �����ϴ�.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 폰트 캐시 재설정 (윈도우에 새로 설치된 폰트 인식)
fm._rebuild() if hasattr(fm, '_rebuild') else None

# 나눔고딕 설정 (시스템에 설치한 경우)
plt.rc('font', family='NanumGothic')

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
# [2/3] 라이브러리 불러오기 + 폰트 등록
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import pandas as pd
import numpy as np

# 설치한 폰트 파일의 위치를 matplotlib에 알려준다 (이 줄이 없으면 한글이 깨집니다)
fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumGothic.ttf')
C:\Windows\Fonts

# seaborn 스타일을 쓰면서 폰트도 같이 지정한다
sns.set_theme(style="whitegrid",
              font="NanumGothic",
              rc={"axes.unicode_minus": False})

print("폰트:", plt.rcParams["font.family"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 import numpy as np
#       8 # 설치한 폰트 파일의 위치를 matplotlib에 알려준다 (이 줄이 없으면 한글이 깨집니다)
# ----> 9 fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumGothic.ttf')
#      11 # seaborn 스타일을 쓰면서 폰트도 같이 지정한다
#      12 sns.set_theme(style="whitegrid",
#      13               font="NanumGothic",
#      14               rc={"axes.unicode_minus": False})
#
# File c:\Users\dsbang\anaconda3\Lib\site-packages\matplotlib\font_manager.py:1136, in FontManager.addfont(self, path)
#    1134     self.afmlist.append(prop)
#    1135 else:
# -> 1136     font = ft2font.FT2Font(path)
#    1137     prop = ttfFontProperty(font)
#    1138     self.ttflist.append(prop)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# %%
# [3/3] 데이터 준비 (강의 노트북과 같은 데이터입니다)

# --- week : 강남점 7일치 요약 ---
week = pd.DataFrame({
    "요일": ["월", "화", "수", "목", "금", "토", "일"],
    "매출": [120, 135, 128, 150, 210, 320, 290],   # 만원
    "방문객": [80, 88, 84, 96, 130, 190, 175],      # 명
})

# --- menu : 메뉴별 판매량 ---
menu = pd.DataFrame({
    "메뉴": ["아메리카노", "라떼", "콜드브루", "마카롱", "샌드위치"],
    "판매량": [420, 260, 180, 95, 130],
})

# --- sales : 3개 지점 x 28일 = 84일치 ---
rng = np.random.default_rng(0)
지점 = np.repeat(["강남", "홍대", "판교"], 28)
요일 = np.tile(["월", "화", "수", "목", "금", "토", "일"], 12)
기본방문 = np.repeat([120, 90, 70], 28)
주말배수 = np.where(np.isin(요일, ["토", "일"]), 1.6, 1.0)
방문객 = (기본방문 * 주말배수 + rng.normal(0, 10, 84)).round()

sales = pd.DataFrame({"지점": 지점, "요일": 요일, "방문객": 방문객})
객단가 = np.where(np.isin(요일, ["토", "일"]), 2.0, 2.4)
sales["일매출"] = (sales["방문객"] * 객단가 + rng.normal(0, 20, 84)).round()

# 요일 순서는 계속 쓰므로 미리 만들어 둡니다
순서 = ["월", "화", "수", "목", "금", "토", "일"]

print(sales.shape)
print(sales.head())
# Out:
# (84, 4)
#    지점 요일    방문객    일매출
# 0  강남  월  121.0  265.0
# 1  강남  화  119.0  298.0
# 2  강남  수  126.0  314.0
# 3  강남  목  121.0  316.0
# 4  강남  금  115.0  261.0

# %% [markdown]
# ---
#
# # Part A. matplotlib 최소 문법

# %% [markdown]
# ### 문제 1. 리스트를 그림으로
#
# `기본` `코드`
#
# `매출2 = [95, 110, 102, 130, 180, 250, 240]` 을 만들고, 가로축에 요일 이름이 나오도록 꺾은선을 그리세요.
#
# **설계문 (빈칸을 채우고 시작하세요)**
# 1. 요일 리스트와 매출2 리스트를 만든다
# 2. ______ 로 꺾은선을 그린다
# 3. 화면에 띄운다
#
# **예상되는 그림**: 가로축 월~일, 토요일이 가장 높은 선 1개

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)
#1.요일 리스트와 매출2 리스트를 만든다
#2. 꺽은선을 그린다
#3.화면에 띄운다

print(week)
print(week.요일)
print(week['요일'])

print(week.매출)
print(week['매출'] )
plt.plot(week['요일'], week['매출'] )
plt.title('요일별 매출')
plt.xlabel('요일')
plt.ylabel('매출')
plt.show
# Out:
#   요일   매출  방문객
# 0  월  120   80
# 1  화  135   88
# 2  수  128   84
# 3  목  150   96
# 4  금  210  130
# 5  토  320  190
# 6  일  290  175
# 0    월
# 1    화
# 2    수
# 3    목
# 4    금
# 5    토
# 6    일
# Name: 요일, dtype: object
# 0    월
# 1    화
# 2    수
# 3    목
# 4    금
# 5    토
# 6    일
# Name: 요일, dtype: object
# 0    120
# 1    135
# 2    128
# 3    150
# 4    210
# 5    320
# 6    290
# Name: 매출, dtype: int64
# 0    120
# 1    135
# 2    128
# 3    150
# 4    210
# 5    320
# 6    290
# Name: 매출, dtype: int64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 문제 2. plt 방식을 ax 방식으로 바꾸기
#
# `기본` `코드`
#
# 문제 1에서 그린 그림을 `fig, ax = plt.subplots()` 방식으로 다시 그리세요.
# `figsize` 는 가로 7, 세로 4로 지정합니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)
# import pandas , matplotlib.plot 
# 데이터 확인
# x 축 요일 확인/생성, y축 매출 리스트 확인/생성 week['요일'], week['매출']
# 그래프 변수 생성
# 
# 그래프 보이기

import pandas as pd 
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot( week['요일'], week['매출'])
ax.set_title("요일별 매출")
ax.set_xlabel("요일")
ax.set_ylabel("매출")
plt.show()

# %% [markdown]
# ### 문제 3. 제목과 축 이름 붙이기
#
# `기본` `코드`
#
# 문제 2의 그림에 아래를 모두 붙이세요.
#
# - 제목: `홍대점 요일별 매출`
# - 가로축 이름: `요일`
# - 세로축 이름: `매출(만원)`
# - 범례에 `매출` 이라고 표시 (선에 label 을 주고 범례를 띄웁니다)

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)
# sales 데이터 확인
# 그레프 변수 선언
print(sales)
#print(sales["지점"])
#print(sales["일매출"]) filter(items=['지점','일매출'])
mask = sales['지점'] == '홍대'

hong_dae_sales = sales[mask]
print(hong_dae_sales['요일'])
print(hong_dae_sales['일매출'])

fig, ax = plt.subplots()
ax.plot(hong_dae_sales['요일'], hong_dae_sales['일매출'])
ax.set_title('홍대점 요일별 매출')
ax.set_xlabel('요일')
ax.set_ylabel('매출(만원)')
ax.legend("매출")
plt.show()
# Out:
#     지점 요일    방문객    일매출
# 0   강남  월  121.0  265.0
# 1   강남  화  119.0  298.0
# 2   강남  수  126.0  314.0
# 3   강남  목  121.0  316.0
# 4   강남  금  115.0  261.0
# ..  .. ..    ...    ...
# 79  판교  수   90.0  211.0
# 80  판교  목   72.0  209.0
# 81  판교  금   64.0  153.0
# 82  판교  토  108.0  218.0
# 83  판교  일  101.0  172.0
#
# [84 rows x 4 columns]
# 28    월
# 29    화
# 30    수
# 31    목
# 32    금
# 33    토
# 34    일
# 35    월
# 36    화
# 37    수
# 38    목
# 39    금
# 40    토
# 41    일
# 42    월
# 43    화
# 44    수
# 45    목
# 46    금
# 47    토
# 48    일
# 49    월
# 50    화
# 51    수
# 52    목
# 53    금
# 54    토
# 55    일
# Name: 요일, dtype: object
# 28    202.0
# 29    225.0
# 30    206.0
# 31    196.0
# 32    240.0
# 33    313.0
# 34    309.0
# 35    249.0
# 36    215.0
# 37    230.0
# 38    237.0
# 39    223.0
# 40    259.0
# 41    303.0
# 42    219.0
# 43    240.0
# 44    212.0
# 45    188.0
# 46    231.0
# 47    333.0
# 48    331.0
# 49    274.0
# 50    225.0
# 51    208.0
# 52    244.0
# ...

# %% [markdown]
# ### 문제 4. 고장난 코드 고치기 - plt와 ax 섞어 쓰기
#
# `기본` `수정`
#
# 아래 코드는 에러가 납니다. **한 번에 한 곳씩** 고쳐서 실행되게 만드세요.
# 고친 뒤에는 무엇이 문제였는지 주석으로 한 줄 적으세요.

# %%
fig, ax = plt.subplots()

ax.plot(week["요일"], week["매출"])

ax.title("요일별 매출")
ax.xlabel("요일")
ax.ylabel("매출(만원)")

plt.show()

# %% [markdown]
# ### 문제 5. 서술 - fig와 ax의 차이
#
# `기본` `서술`
#
# 아래 두 질문에 한 문장씩 답하세요. (아래 마크다운 칸을 두 번 클릭해서 직접 적으세요)
#
# 1. `fig` 와 `ax` 는 각각 무엇인가?
# 2. 전체 제목을 붙일 때 `ax.set_title()` 이 아니라 `fig.suptitle()` 을 쓰는 이유는?
#
# **내 답**
# 1.
# 2.

# %% [markdown]
# ### 문제 6. 한글이 깨졌을 때
#
# `심화` `코드`
#
# 동료가 이렇게 물어봅니다.
#
# > "그래프에 한글이 전부 네모로 나와요. 제 코드가 잘못됐나요?"
#
# 1. 원인이 무엇인지 한 문장으로 답하세요.
# 2. 해결하는 코드 3줄을 적으세요. (설치는 이미 되어 있다고 가정)
#
# **내 답 (1번)**

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ---
#
# # Part B. 질문 4종 - 그림 4종

# %% [markdown]
# ### 문제 7. 질문과 그림 짝짓기
#
# `기본` `서술`
#
# 아래 네 질문에 각각 어떤 그래프가 맞는지 적으세요.
# (꺾은선 / 막대 / 산점도 / 히스토그램 중에서 고릅니다)
#
# | 질문 | 내 답 |
# |---|---|
# | (1) 지난 12개월 회원 수가 어떻게 변했나 | |
# | (2) 지점 5곳 중 어디가 매출이 가장 높나 | |
# | (3) 광고비를 많이 쓴 달은 매출도 높았나 | |
# | (4) 우리 손님 나이는 주로 몇 살대에 몰려 있나 | |

# %% [markdown]
# ### 문제 8. 꺾은선 - 요일별 방문객
#
# `기본` `코드`
#
# `week` 을 써서 요일별 **방문객** 꺾은선을 그리세요.
#
# - 각 데이터 점에 동그라미 마커를 찍을 것
# - 제목: `강남점 요일별 방문객`
# - 세로축 이름에 단위를 포함할 것

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 9. 막대 - 판매량이 큰 순서로
#
# `기본` `코드`
#
# `menu` 를 판매량이 **큰 순서로 정렬**해서 세로 막대로 그리세요.
#
# - 제목: `메뉴별 판매량`
# - 세로축은 0에서 시작하도록 지정할 것

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 10. 가로 막대로 바꾸기
#
# `기본` `코드`
#
# 문제 9의 그림을 **가로 막대**로 바꾸고, 판매량 1등이 **맨 위**에 오도록 만드세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 11. 산점도 - 방문객과 일매출
#
# `기본` `코드`
#
# `sales` 를 써서 가로축 방문객, 세로축 일매출인 산점도를 그리세요.
# 점이 84개라 겹치므로 **투명도와 점 크기**를 조정하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 12. 서술 - 산점도를 보고 할 수 있는 말
#
# `심화` `서술`
#
# 문제 11의 산점도를 보고, 아래 두 문장 중 **맞는 것**을 고르고 이유를 적으세요.
#
# - (가) 방문객이 늘어서 매출이 늘었다.
# - (나) 방문객이 많은 날은 매출도 높은 경향이 있다.
#
# **내 답**: (   )
# **이유**:

# %% [markdown]
# ### 문제 13. 히스토그램 - bins를 바꿔 보기
#
# `기본` `코드`
#
# `sales["일매출"]` 의 히스토그램을 **가로 3칸**에 그리되, bins 를 각각 `5`, `20`, `60` 으로 다르게 주세요.
# 각 칸의 제목에 bins 값이 나오게 하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 14. 서술 - 막대그래프와 히스토그램의 차이
#
# `기본` `서술`
#
# 둘 다 막대인데 무엇이 다른지, **가로축과 세로축이 각각 무엇인지**를 기준으로 설명하세요.
#
# **막대그래프**
# - 가로축:
# - 세로축:
#
# **히스토그램**
# - 가로축:
# - 세로축:

# %% [markdown]
# ### 문제 15. 고장난 코드 고치기 - 잘못된 그래프 선택
#
# `심화` `수정`
#
# 아래 코드는 **에러 없이 실행됩니다.** 그런데 그래프 선택이 잘못됐습니다.
# 무엇이 문제인지 주석으로 적고, 올바른 그래프로 고치세요.

# %%
fig, ax = plt.subplots(figsize=(7, 4))

ax.plot(menu["메뉴"], menu["판매량"], marker="o")

ax.set_title("메뉴별 판매량")
plt.show()

# %% [markdown]
# ---
#
# # Part C. 여러 그림을 한 판에

# %% [markdown]
# ### 문제 16. 가로 2칸
#
# `기본` `코드`
#
# 가로 2칸을 만들어 왼쪽에는 `week` 의 요일별 매출 꺾은선, 오른쪽에는 요일별 방문객 꺾은선을 그리세요.
# 각 칸에 제목과 세로축 이름(단위 포함)을 붙이고, 그림끼리 겹치지 않게 정리하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 17. 2행 2열 대시보드
#
# `기본` `코드`
#
# 2행 2열 4칸을 만들어 아래를 배치하세요. 전체 제목은 `커피 대시보드` 입니다.
#
# | 위치 | 내용 |
# |---|---|
# | 왼쪽 위 | 요일별 매출 꺾은선 (week) |
# | 오른쪽 위 | 메뉴별 판매량 막대 (menu) |
# | 왼쪽 아래 | 방문객-일매출 산점도 (sales) |
# | 오른쪽 아래 | 일매출 히스토그램 (sales) |

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 18. 축을 맞춰서 비교하기
#
# `기본` `코드`
#
# 지점 3곳(`강남`, `홍대`, `판교`)의 **일매출 히스토그램**을 가로 3칸에 그리세요.
# 단, 세 칸의 **세로축 눈금이 같아야** 합니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 19. 고장난 코드 고치기 - AttributeError
#
# `기본` `수정`
#
# 아래 코드는 이런 에러가 납니다.
#
# ```
# AttributeError: 'numpy.ndarray' object has no attribute 'set_title'
# ```
#
# 에러 메시지를 읽고 원인을 주석으로 적은 뒤 고치세요.

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4))

axes.plot(week["요일"], week["매출"])
axes.set_title("요일별 매출")

plt.show()

# %% [markdown]
# ### 문제 20. 서술 - 겹칠까 나눌까
#
# `심화` `서술`
#
# 아래 두 경우에 대해, 한 칸에 겹쳐 그릴지 칸을 나눌지 고르고 이유를 적으세요.
#
# (1) 강남점 매출과 홍대점 매출 (둘 다 만원)
# (2) 일매출(만원)과 방문객(명)
#
# **내 답**
# (1)
# (2)

# %% [markdown]
# ---
#
# # Part D. 꾸미기와 저장

# %% [markdown]
# ### 문제 21. 선 스타일 바꾸기
#
# `기본` `코드`
#
# `week` 의 요일별 매출을 아래 조건으로 그리세요.
#
# - 색: `#e8590c`
# - 선 모양: 점선
# - 선 굵기: 2
# - 마커: 네모, 크기 8

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 22. 축과 눈금 정리하기
#
# `기본` `코드`
#
# 메뉴별 판매량 막대그래프를 그리고 아래를 모두 적용하세요.
#
# - 세로축을 0부터 500까지로 고정
# - 가로축 글자를 30도 기울이기
# - 가로 방향 격자선만 연하게 (alpha 0.3)
# - 격자선이 막대 **뒤로** 가게 하기

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 23. 하나만 강조하기
#
# `기본` `코드`
#
# 요일별 매출 막대를 그리되, **금요일 하나만** 주황색(`#e8590c`)이고 나머지는 회색(`#adb5bd`)이 되게 하세요.
#
# 힌트: 같은 ax 에 두 번 그리면 덮어써집니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 24. 화살표로 설명 붙이기
#
# `심화` `코드`
#
# 요일별 매출 꺾은선을 그리고, 토요일 지점(320)을 가리키는 화살표와 함께 `최고 매출` 이라는 글자를 넣으세요.
# 글자는 수요일 위쪽(360 근처)에 놓습니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 25. 파일로 저장하기
#
# `기본` `코드`
#
# 문제 23의 강조 막대그래프를 `금요일매출.png` 로 저장하세요.
#
# - 해상도 150
# - 제목이 잘리지 않게 저장
# - 저장이 끝나면 `저장 완료` 를 출력

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 26. 제목 고쳐 쓰기
#
# `심화` `코드`
#
# 아래 제목들을 **발견한 사실이 드러나는 제목**으로 고쳐 쓰세요.
# (숫자를 쓸 거면 아래 코드 칸에서 계산해서 확인한 뒤 쓰세요)
#
# | 지금 제목 | 고친 제목 |
# |---|---|
# | 요일별 매출 | |
# | 지점별 일매출 | |
# | 메뉴별 판매량 | |

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ---
#
# # Part E. seaborn

# %% [markdown]
# ### 문제 27. seaborn 한 줄로 바꾸기
#
# `기본` `코드`
#
# 아래 matplotlib 코드와 **같은 결과**를 seaborn 한 줄로 만드세요.
#
# ```python
# 평균 = sales.groupby("지점")["일매출"].mean()
# fig, ax = plt.subplots()
# ax.bar(평균.index, 평균.values)
# ```
#
# 제목과 세로축 이름도 붙이세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 28. barplot이 무엇을 계산했는지 확인하기
#
# `기본` `코드`
#
# `sales` 는 84행인데 `sns.barplot(data=sales, x="지점", y="일매출")` 을 그리면 막대가 3개만 나옵니다.
#
# 1. seaborn 이 무엇을 계산한 것인지 아래 코드로 **직접 확인**하세요.
# 2. **합계**로 바꾼 막대그래프도 그려서 나란히 비교하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 29. countplot과 order
#
# `기본` `코드`
#
# `sales` 의 **요일별 데이터 개수**를 countplot 으로 그리세요.
# 요일이 월화수목금토일 순서로 나와야 합니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 30. hue로 집단 나누기
#
# `기본` `코드`
#
# 가로 2칸을 만들어 왼쪽에는 `sales["일매출"]` 전체 히스토그램, 오른쪽에는 **지점별로 색을 나눈** 히스토그램을 그리세요.
# 오른쪽은 지점끼리 쌓이도록(stack) 하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 31. 산점도에 hue와 style 넣기
#
# `기본` `코드`
#
# `sales` 의 방문객-일매출 산점도를 그리되, 지점을 **색과 모양 둘 다로** 구분하세요.
# 점 크기는 70으로 합니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 32. 박스플롯에 실제 점 뿌리기
#
# `기본` `코드`
#
# 지점별 일매출 분포를 박스플롯으로 그리되, **실제 데이터 점도 위에 뿌리세요.**
#
# - 상자는 연한 회색(`#dee2e6`), 폭 0.5
# - 점은 진한 회색(`#495057`), 크기 4, 투명도 0.6, 좌우로 살짝 흩뿌리기

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 33. 서술 - 박스플롯 읽기
#
# `심화` `서술`
#
# 박스플롯에서 아래 다섯 부분이 각각 무엇을 뜻하는지 적으세요.
#
# 1. 상자 안의 가로선:
# 2. 상자의 아래 끝:
# 3. 상자의 위 끝:
# 4. 위아래로 뻗은 수염:
# 5. 수염 밖의 점:
#
# 그리고 **막대그래프 대신 박스플롯을 쓰면 무엇을 더 알 수 있는지** 한 문장으로 적으세요.

# %% [markdown]
# ### 문제 34. 피벗 + 히트맵
#
# `심화` `코드`
#
# `sales` 를 **행=지점, 열=요일, 값=일매출 평균** 형태로 재구성한 뒤 히트맵을 그리세요.
#
# - 요일 순서는 월~일
# - 칸 안에 숫자를 소수점 없이 표시
# - 세로축 글자가 누워 있으면 바로 세우기
#
# 히트맵을 그리기 **전에** 피벗 결과를 print 로 눈으로 확인하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 35. seaborn으로 그리고 matplotlib으로 다듬기
#
# `심화` `코드`
#
# 요일별 평균 일매출 막대그래프를 seaborn 으로 그린 뒤, matplotlib 으로 **전체 평균 가로 기준선**을 주황 점선으로 추가하세요.
# 범례에 `전체 평균` 이라고 표시합니다.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 36. 고장난 코드 고치기 - catplot에 ax
#
# `심화` `수정`
#
# 아래 코드는 이런 에러가 납니다.
#
# ```
# TypeError: catplot() got an unexpected keyword argument 'ax'
# ```
#
# 원인을 주석으로 적고, **두 가지 방법**으로 각각 고치세요.
# - 방법 1: 칸 단위 함수로 바꾸기
# - 방법 2: catplot 을 그대로 쓰되 ax 를 빼기

# %%
fig, ax = plt.subplots(figsize=(8, 4))

sns.catplot(data=sales, x="요일", y="일매출",
            kind="bar", order=순서, errorbar=None, ax=ax)

plt.show()

# %% [markdown]
# ---
#
# # Part F. 거짓말하는 그래프

# %% [markdown]
# ### 문제 37. 세로축 자르기 재현하기
#
# `기본` `코드`
#
# 아래 데이터로 **같은 데이터, 다른 인상**의 막대그래프 2개를 가로로 나란히 그리세요.
#
# ```python
# q = pd.DataFrame({"분기": ["1Q","2Q","3Q","4Q"],
#                   "재구매율": [61.2, 61.8, 62.1, 62.6]})
# ```
#
# - 왼쪽: 세로축 0~100
# - 오른쪽: 세로축 61~63
#
# 그린 뒤 실제 차이가 몇 퍼센트포인트인지 출력하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 38. 이중축 만들고 문제점 찾기
#
# `심화` `코드`
#
# `week` 의 매출(만원)과 방문객(명)을 **이중축**으로 한 칸에 그리세요.
# (`ax2 = ax1.twinx()` 를 씁니다)
#
# 그린 뒤, 이 그림의 문제점을 아래 코드 주석에 두 줄로 적으세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 39. 파이차트 vs 가로 막대
#
# `기본` `코드`
#
# `menu` 를 왼쪽은 파이차트, 오른쪽은 정렬된 가로 막대로 나란히 그리세요.
# 그린 뒤 **콜드브루와 샌드위치 중 어느 쪽이 더 많이 팔렸는지** 두 그림에서 각각 몇 초 만에 답할 수 있었는지 적으세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 40. 서술 - 이 그래프를 의심하라
#
# `심화` `서술`
#
# 회의에서 아래 그래프를 봤습니다.
#
# > 막대그래프 3개. 우리 회사 만족도 4.6점, A사 4.4점, B사 4.2점.
# > 우리 회사 막대가 B사 막대의 **세 배 높이**로 그려져 있음.
#
# 1. 이 그래프에서 가장 먼저 확인해야 할 것은?
# 2. 왜 그렇게 보였을지 이유를 적으세요.
#
# **내 답**
# 1.
# 2.

# %% [markdown]
# ---
#
# # Part G. 종합

# %% [markdown]
# ### 문제 41. 종합 1 - 객단가를 직접 찾아내기
#
# `심화` `코드`
#
# **질문**: 주말에는 손님이 늘어난 만큼 매출도 늘어나는가?
#
# **할 일**
# 1. `sales` 에 `객단가` 열을 새로 만든다 (일매출 ÷ 방문객)
# 2. 요일별 평균 객단가를 막대그래프로 그린다 (주말 2칸을 강조색으로)
# 3. 평일 평균과 주말 평균 객단가를 계산해서 출력한다
# 4. 제목에 **발견한 사실**을 쓴다 (숫자는 계산해서 확인한 값으로)
#
# 설계문을 먼저 쓰고 시작하세요.

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 42. 종합 2 - 주말 효과 비교 대시보드
#
# `심화` `코드`
#
# **질문**: 주말 효과는 세 지점에서 똑같이 나타나는가?
#
# **조건**
# - 가로 2칸
# - 왼쪽: 지점별 요일 흐름을 선으로 (hue 사용)
# - 오른쪽: 지점 x 요일 평균 일매출 히트맵
# - 각 칸에 제목, 전체 제목도 붙일 것

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)

# %% [markdown]
# ### 문제 43. 종합 3 - 발표용 한 장 완성하기
#
# `심화` `코드`
#
# 사장님께 드릴 그림 **한 장**을 완성하고 파일로 저장하세요.
#
# **조건**
# - 지점별 평균 일매출 가로 막대
# - 1등 지점만 강조색, 나머지는 회색
# - 위/오른쪽 테두리 제거
# - 제목에 발견한 사실 (숫자는 계산해서 확인)
# - 세로축 이름은 비우기 (이미 지점 이름이 적혀 있으므로)
# - `지점별매출.png` 로 저장 (해상도 150, 잘림 없이)

# %%
# --- 여기부터 직접 작성하세요 ---
# (설계문을 먼저 쓰고, 한 줄씩 번역하세요)
