# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ***
# ## 6. Sequence Item Selection💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래 리스트(List)에서` **`apple, kiwi`** `를 추출해서` **`대문자`** `리스트로 출력하세요.` **`가능한 다양한`** `방법으로 코딩해보세요.`
#
#
#
# ```python
# x = ["grapes", "mango", "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]
#
# 출력 결과 : [APPLE, KIWI]
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
x = ["grapes", "mango", "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]

# %%
print(bool(1))
print(bool(1 or 0))
print(bool(1 and 0))
# Out:
# True
# True
# False

# %%
x = ["grapes", "mango", 'a', "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]

print(len(x))
# print(x[4])
# print(x[1])
l = []
for i in range(len(x)):
    if 1 and 1:
        # print(x[i])
        l.append(x[i].upper())


l
# Out:
# 13
# ['GRAPES',
#  'MANGO',
#  'A',
#  'ORANGE',
#  'PEACH',
#  'APPLE',
#  'LIME',
#  'BANANA',
#  'CHERRY',
#  'TOMATO',
#  'KIWI',
#  'BLUEBERRY',
#  'WATERMELON']

# %%
x = ["grapes", "mango", 'a', "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]

print(len(x))
# l = []
# for i in x:
#     # # print(f'for >>>> {i}')
#     # if i == 'apple':
#     #     # print(f'if >>>> {i}')
#     #     l.append(i.upper())
#     # if i == 'kiwi':
#     #     # print(f'if_if >>>> {i}')
#     #     l.append(i.upper())
#     if i == 'apple' or i == 'kiwi':
#         # print(i)
#         l.append(i.upper())

for i in range(5):
    print('hi')


# print(f'print >>>> {l}')
# Out:
# 13
# hi
# hi
# hi
# hi
# hi

# %%
for i in range(len(x)):
    if x[i] == 'apple':
        print(i)
# Out:
# 5

# %%
# print(bool(1))
# print(bool(0))
# print(bool('a'))
# print(bool('b'))
# print(bool(''))
# print(bool(' '))
# print(len('seoul'))
# print(len('s    eoul'))
print(bool([]))
print(bool([                 ]))
a = [       ]
print(a)
# Out:
# False
# False
# []

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 파이썬에서 사용가능한 반복문(for, while)은 기억하시죠? -> (break, continue) 필수 기억!
# # 시퀀스 자료형(데이터의 값이 연속적으로 이루어진 자료구조) : List, Tuple, Str, Range..
# # filter(f, iterable) 함수는 정말 많이 사용해요.(map 함수도 중요!)
# # lambda expression(형식)은 다른 함수의 인수 전달 형태로 사용해요.
# ```
# </div>
# </details>

# %%
def hi(name, age):
    name1 = name+'skdjfksdfjsk'
    return name1

a = hi('babo', 18)
b = hi('hoho', 28)

print(a)

print(a+'hoho')
print(b+'sdfklsdjflksdj')
# Out:
# name >>>> babo님
# age >>>> 18세
# name >>>> hoho님
# age >>>> 28세
# babo
# babohoho
# hohosdfklsdjflksdj

# %%
# 매개변수 x return x
# def hi():
#     print('hoho')
# hi()
# # 매개변수 o return x
# def hello(sdlkfjhsdlkfjskldjfskl, sflksjfksljk):
#     print(sdlkfjhsdlkfjskldjfskl)
#
# hello('hoho', '18181818')
#
# 매개변수 o return o
def hello(name):
    a = name
    return a

# return 종료
def check(score):
    if score >= 88:
        # print(f'if')
        return True
    return False

if check(88):
    print('합격')
# Out:
# 합격

# %%
def double(x):
    return x * 2

a = lambda x : x * 2
print(a(10))
# Out:
# 20

# %%
x = ["grapes", "mango", 'a', "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]

l = []
for i in range(len(x)):
    if x[i] == 'apple' or x[i] == 'kiwi':
        l.append(x[i].upper())



a = '18'
b = int(a)
print(b)

def double(x):
    return x * 2

# print(list(map(double, [1, 2, 3, 4, 5])))
# print(list(map(lambda a:a * 2, [1, 2, 3, 4, 5])))


# print()
# print(list( filter(lambda a: a== 'apple' or a == 'kiwi', x)))
# list(map(lambda b: b.upper(), filter(lambda a: a== 'apple' or a == 'kiwi', x)))
# Out:
# 18
# [2, 4, 6, 8, 10]
# ['APPLE', 'KIWI']

# %%
x = ["grapes", "mango", 'a', "orange", "peach", "apple", "lime", "banana", "cherry", "tomato", "kiwi", "blueberry", "watermelon"]

# l = []
# for i in range(len(x)):
#     if x[i] == 'apple' or x[i] == 'kiwi':
#         l.append(x[i].upper())

hoho = [a.upper() for a in x if a =='apple' or a == 'kiwi']
print(hoho)
# Out:
# ['APPLE', 'KIWI']

# %% [markdown]
# ***
