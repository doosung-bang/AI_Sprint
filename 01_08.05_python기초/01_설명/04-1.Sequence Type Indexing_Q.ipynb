# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ***
# ## 4. Sequence Type Indexing💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래 리스트(List)에서` **`index 함수`** `를 포함한 다양한 방법으로` **`"Banana"`** `를 인덱싱(추출) 해보세요.` `출력 결과와 같아야 되요.`
#
#
# ```python
# # 직접 접근, index함수 사용 가능
# x = ['Orange', 'Cherry', 'Apple', 'Kiwi', 'Banana', 'Strawberry']
#
# 출력 결과 : Banana
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
x = ['Orange', 'Cherry', 'Apple', 'Kiwi', 'Banana', 'Strawberry']

print(x)
print(x[4])

print(f'안정적으로 확인하고 싶어 >>> {'Banan' in x}')
if 'Banana' in x:
    print('hoho')
    print(x[x.index('Banan')])
# [x.index('Banan')]
# print(f'index >>>> {x[x.index('Banana')]}')

# hoho = 'sklfjsdlkfjsdlkjfklsdjfklsjsdkl'
# Out:
# ['Orange', 'Cherry', 'Apple', 'Kiwi', 'Banana', 'Strawberry']
# Banana
# 안정적으로 확인하고 싶어 >>> False
# hoho
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 9
#       5
#       6 print(f'안정적으로 확인하고 싶어 >>> {'Banan' in x}')
#       7 if 'Banana' in x:
#       8     print('hoho')
# ----> 9     print(x[x.index('Banan')])
#      10 # [x.index('Banan')]
#      11 # print(f'index >>>> {x[x.index('Banana')]}')
#      12
#
# ValueError: 'Banan' is not in list

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 시퀀스 자료형(데이터의 값이 연속적으로 이루어진 자료구조) : List, Tuple, Str, Range..
# # List 관련 함수는 중요!
# # cmp, len, max, min, list, append, count, extend, index, insert, pop, remove, reverse, sort..
# # index 함수 대소문자 구분
# # sort, sorted 함수 차이도 중요
# ```
# </div>
# </details>

# %% [markdown]
# ***
