# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ***
# ## 16. Sigma Calculator💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래와 같이` **`N`** `까지` **`합(Sigma)`** `을 구하는 공식을` **`함수`** `형태로 작성 후 출력하세요.`  **`다양한 방법 사용`**
#
# ![16-1](../../source/16-1.png)
#
# ```python
#
# 입력 : 10
#
# 출력 결과 : 55
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역
import this

# %%
print('apple')
print('banana')
print('kiwi')
print('melon')
# Out:
# apple
# banana
# kiwi
# melon

# %%
fruits = ['apple', 'banana', 'kiwi', 'melon']

# for i in fruits:
for i in ['apple', 'banana', 'kiwi', 'melon']:
    print(f'for >>> {i}')
    if i == 'banana':
        print('hoho')
# Out:
# for >>> apple
# for >>> banana
# hoho
# for >>> kiwi
# for >>> melon

# %%
fruits = ['apple', 'banana', 'kiwi', 'melon']

# for i in fruits:
for i in ['apple', 'banana', 'kiwi', 'melon']:
    print(f'for >>> {i}')
    if i != 'banana':
        print('hoho')
# Out:
# for >>> apple
# hoho
# for >>> banana
# for >>> kiwi
# hoho
# for >>> melon
# hoho

# %%
fruits = ['apple', 'banana', 'kiwi', 'melon']

# for i in fruits:
for i in ['apple', 'banana', 'kiwi', 'melon']:
    print(f'for >>> {i}')
    if i == 'banana':
        print('hoho')
    print('T-T')
# Out:
# for >>> apple
# T-T
# for >>> banana
# hoho
# T-T
# for >>> kiwi
# T-T
# for >>> melon
# T-T

# %%
# for i in range(4):
#     print(i)


# print(list(range(4)))

for i in range(18):
    # print(i)
    print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
a = [1, 2, 3, 4, 5]
# print(a[3])

for i in range(4):
    print(a[i])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 파이썬 언어 활용 분야인 데이터 사이언스 분야에서 다양한 방정식(공식) 구현 필요성
# # 제공되지 않는 수학 공식을 코드로 표현하는 능력 중요
# # 참조 : https://www.mathsisfun.com/numbers/sigma-calculator.html
# ```
# </div>
# </details>

# %% [markdown]
# ***

# %%
d = {'a': 17,'b': 114,'c': 247, 'd': 362, 'e': 220, 'f': 728, 'g': -283, 'h': 922}

print(d.keys())
print(d.values())
print(d.items())
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
# dict_values([17, 114, 247, 362, 220, 728, -283, 922])
# dict_items([('a', 17), ('b', 114), ('c', 247), ('d', 362), ('e', 220), ('f', 728), ('g', -283), ('h', 922)])

# %%
for k in d.keys():
    print(k)
# Out:
# a
# b
# c
# d
# e
# f
# g
# h

# %%
a = [('a', 17), ('b', 114), ('c', 247), ('d', 362), ('e', 220), ('f', 728), ('g', -283), ('h', 922)]

print(a[3])
# Out:
# ('d', 362)

# %%
d = {'a': 17,'b': 114,'c': 247, 'd': 362, 'e': 220, 'f': 728, 'g': -283, 'h': 922}

for k, v in d.items():
    print(k)
    print(v)
# Out:
# a
# 17
# b
# 114
# c
# 247
# d
# 362
# e
# 220
# f
# 728
# g
# -283
# h
# 922
