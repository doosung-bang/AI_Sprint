# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ***
# ## 21. String Split By Delimiter💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래와 같은` **`문장을 공백`** `으로` **`구분 후`** `단어 개수를 출력하는` **`함수`** `를 작성 후 실행하세요.` **`input 함수 가능`**
#
#
# ```python
# in_str = "Suppose we have few words that are separated by spaces."
#
# 출력 결과 : 10
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역
#import this
in_str = "Suppose we have few words that are separated by spaces."

print(f'split()함수 이용후 리스트 갯수 카운트: {len(in_str.split(' '))}개')

def cnt_words( text=None ):
    if text is None:
        text = input("문장을 입력하세요: ")
    else:
        words = text.split(' ')
        words_cnt = len(words)
        print(f'단어 리스트=>>>> {words}')
        print(f'단어 숫자  =>>>> {words_cnt}개')
    return words_cnt

cnt_words(in_str)
# Out:
# split()함수 이용후 리스트 갯수 카운트: 10개
# 단어 리스트=>>>> ['Suppose', 'we', 'have', 'few', 'words', 'that', 'are', 'separated', 'by', 'spaces.']
# 단어 숫자  =>>>> 10개
# 10

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # Python split() 함수는 자주사용해요.
# # string.split(separator, maxsplit) : 구분자, 분할 수
# # 기본 분리 지정자는 공백
# # 문자열을 구분 후 리스트로 변환
# ```
# </div>
# </details>

# %% [markdown]
# ***
